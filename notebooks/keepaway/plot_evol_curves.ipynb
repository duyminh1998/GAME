# %%
from GAME.utils.config import config
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

config_data = config()

# %%
# keepaway_GAME_evol_folder_path = os.path.join(config_data['output_path'], '11122022 Evolve keepaway Maps with GAME 2000 FE')
keepaway_GAME_evol_folder_path = os.path.join(config_data['output_path'], 'Final Presentation', '12032022 Evolve keepaway Maps with GAME 10000 FE One-Point CX 0.05 Mutation Rate')
trials = 10
GAME_fitness_evaluations = [i for i in range(200, 2009, 100)]
GAME_trials_best_fitness = []
for trial in range(trials):
    trial_stats = os.path.join(keepaway_GAME_evol_folder_path, 'trial{}_stats.txt'.format(trial))
    trial_df = pd.read_csv(trial_stats, index_col=False, header=0)    
    # if len(np.array(trial_df['best_fitness'].to_list())) == 99:
    GAME_trials_best_fitness.append(np.array(trial_df['best_fitness'][:19].to_list()))
GAME_trials_best_fitness = np.array(GAME_trials_best_fitness, dtype=object)
GAME_trials_best_fitness = GAME_trials_best_fitness.mean(axis = 0)
GAME_trials_best_fitness = [0.35] + list(GAME_trials_best_fitness)
GAME_fitness_evaluations = [0] + GAME_fitness_evaluations

keepaway_GAMERMHC_evol_folder_path = os.path.join(config_data['output_path'], '11122022 Evolve keepaway Maps with GAME_RMHC 2000 FE')
trials = 10
RMHC_fitness_evaluations = np.arange(2, 2001, 1, dtype=int)
RMHC_trials_best_fitness = []
for trial in range(trials):
    trial_stats = os.path.join(keepaway_GAMERMHC_evol_folder_path, 'trial{}_stats.txt'.format(trial))
    trial_df = pd.read_csv(trial_stats, index_col=False, header=0)    
    RMHC_trials_best_fitness.append(trial_df['best_fitness'].to_list())
RMHC_trials_best_fitness = np.array(RMHC_trials_best_fitness)
RMHC_trials_best_fitness = RMHC_trials_best_fitness.mean(axis = 0)

# %%
len(GAME_fitness_evaluations)
# Out:
# 20

# %%
plt.plot(GAME_fitness_evaluations, GAME_trials_best_fitness, label='GAME')
plt.plot(RMHC_fitness_evaluations, RMHC_trials_best_fitness, label='GAME-RMHC', alpha=0.5)
plt.legend()
plt.ylim(0, 1.1)
plt.xlim(0, 2000)
plt.xticks([i for i in range(0, 2000, 200)])
plt.yticks([i*0.1 for i in range(0, 11, 1)])
plt.xlabel('Fitness evaluations')
plt.ylabel('Best fitness')
plt.title('Evolutionary curves for GAME and GAME-RMHC on Keepaway')
plt.show()

# %%
summation = 0
for i in range(10):
    with open(os.path.join(keepaway_GAME_evol_folder_path, 'trial{}_population_results.txt'.format(i)), 'r') as f:
        lines = f.readlines()
        for j in range(1, 21):
            if 'I' == lines[j][0]:
                summation += float(lines[j].split()[-1])
summation / 200
# Out:
# 0.35773437399170005

# %%
trial_stats = os.path.join(keepaway_GAMERMHC_evol_folder_path, 'trial0_stats.txt')
trial_df = pd.read_csv(trial_stats, index_col=False, header=0)
trial_df.tail()
# Out:
#       trial_no  generation  fitness_evaluations  comparisons  best_fitness  \
# 1994         0        1994                 1996            2      0.925806
# 1995         0        1995                 1997            2      0.925806
# 1996         0        1996                 1998            2      0.925806
# 1997         0        1997                 1999            2      0.925806
# 1998         0        1998                 2000            2      0.925806
#
#             best_fitness_ind_ID
# 1994  0119244490108999949590000
# 1995  0119244490108999949590000
# 1996  0119244490108999949590000
# 1997  0119244490108999949590000
# 1998  0119244490108999949590000

# %% [markdown]
# #### GAME

# %%
MC3D_GAME_evol_folder_path = os.path.join(config_data['output_path'], '11122022 Evolve keepaway Maps with GAME 2000 FE')
trials = 10

# %%
trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'trial0_stats.txt')
trial_df = pd.read_csv(trial_stats, index_col=False, header=0)

# %%
trial_df.tail()
# Out:
#     trial_no  generation  fitness_evaluations  comparisons  best_fitness  \
# 94         0          94                 1937          792      0.899923
# 95         0          95                 1957          958      0.899923
# 96         0          96                 1977          852      0.899923
# 97         0          97                 1997          812      0.899923
# 98         0          98                 2017          890      0.899923
#
#            best_fitness_ind_ID
# 94  05973432612988974510120000
# 95  05973432612988974510120000
# 96  05973432612988974510120000
# 97  05973432612988974510120000
# 98  05973432612988974510120000

# %%
GAME_fitness_evaluations = [i for i in range(40, 2020, 20)]
GAME_trials_best_fitness = []

# %%
for trial in range(trials):
    trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'trial{}_stats.txt'.format(trial))
    trial_df = pd.read_csv(trial_stats, index_col=False, header=0)    
    if len(np.array(trial_df['best_fitness'].to_list())) == 99:
        GAME_trials_best_fitness.append(np.array(trial_df['best_fitness'].to_list()))

# %%
GAME_trials_best_fitness = np.array(GAME_trials_best_fitness, dtype=object)
GAME_trials_best_fitness = GAME_trials_best_fitness.mean(axis = 0)

# %%
plt.plot(GAME_fitness_evaluations, GAME_trials_best_fitness)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# #### GAME_SAHC

# %%
MC3D_GAME_evol_folder_path = os.path.join(config_data['output_path'], '11122022 Evolve keepaway Maps with GAME_SAHC 2000 FE')
trials = 10

# %%
trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'trial0_stats.txt')
trial_df = pd.read_csv(trial_stats, index_col=False, header=0)
trial_df.tail()
# Out:
#    trial_no  generation  fitness_evaluations  comparisons  best_fitness  \
# 4         0           4                 1181          472      0.710095
# 5         0           5                 1417          472      0.754857
# 6         0           6                 1653          472      0.799396
# 7         0           7                 1889          472      0.826153
# 8         0           8                 2125          472      0.852817
#
#            best_fitness_ind_ID
# 4  980411437101919454116121100
# 5   98044437101919454116121100
# 6  980444371012919454116121100
# 7  980444371012919494116121100
# 8  980444371012999494116121100

# %%
SAHC_fitness_evaluations = np.arange(237, 2200, (2200 - 237) / 9, dtype=int)
SAHC_trials_best_fitness = []

# %%
for trial in range(trials):
    trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'trial{}_stats.txt'.format(trial))
    trial_df = pd.read_csv(trial_stats, index_col=False, header=0)    
    SAHC_trials_best_fitness.append(trial_df['best_fitness'].to_list())

# %%
SAHC_trials_best_fitness = np.array(SAHC_trials_best_fitness)
SAHC_trials_best_fitness = SAHC_trials_best_fitness.mean(axis = 0)

# %%
plt.plot(SAHC_fitness_evaluations, SAHC_trials_best_fitness)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
plt.plot(GAME_fitness_evaluations, GAME_trials_best_fitness, label='GAME')
plt.plot(SAHC_fitness_evaluations, SAHC_trials_best_fitness, label='GAME_SAHC')
plt.ylim(0, 1)
plt.xlim(0, 2000)
# Out:
# (0.0, 2000.0)

# %% [markdown]
# #### RMHC

# %%
MC3D_GAME_evol_folder_path = os.path.join(config_data['output_path'], '11112022 Evolve MC Maps with GAME_RMHC 240 FE')
trials = 10

# %%
trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'MC_trial2_stats.csv')
trial_df = pd.read_csv(trial_stats, index_col=False, header=0)
trial_df.tail()
# Out:
#      trial_no  generation  fitness_evaluations  comparisons  best_fitness  \
# 234         2         234                  236            2      0.990164
# 235         2         235                  237            2      0.990164
# 236         2         236                  238            2      0.990164
# 237         2         237                  239            2      0.990164
# 238         2         238                  240            2      0.990164
#
#      best_fitness_ind_ID
# 234             10100000
# 235             10100000
# 236             10100000
# 237             10100000
# 238             10100000

# %%
RMHC_fitness_evaluations = np.arange(2, 240, 1, dtype=int)
RMHC_trials_best_fitness = []

# %%
for trial in range(trials):
    trial_stats = os.path.join(MC3D_GAME_evol_folder_path, 'MC_trial{}_stats.csv'.format(trial))
    trial_df = pd.read_csv(trial_stats, index_col=False, header=0)    
    RMHC_trials_best_fitness.append(trial_df['best_fitness'].to_list())

# %%
RMHC_trials_best_fitness = np.array(RMHC_trials_best_fitness)
RMHC_trials_best_fitness = RMHC_trials_best_fitness.mean(axis = 0)

# %%
plt.plot(RMHC_fitness_evaluations, RMHC_trials_best_fitness[:-1])

# %%
plt.plot(GAME_fitness_evaluations, GAME_trials_best_fitness, label='GAME')
plt.plot(SAHC_fitness_evaluations, SAHC_trials_best_fitness, label='GAME_SAHC')
plt.plot(RMHC_fitness_evaluations, RMHC_trials_best_fitness[:-1], label='GAME_RMHC')
plt.legend()
plt.ylim(0, 1)
plt.xlim(0, 240)
# Out:
# (0.0, 240.0)
